# %%
# %run "C:\Users\kassenov_r\report-automation\suburban_schools\sor_soch_cleaning\data_cleaning.ipynb"
# Out:
# !Attention! : 'df4' has no school name
# !Attention! : 'df6' has no school name
# !Attention! : 'df16' has no school name
# !Attention! : 'df22' has no school name
# !Attention! : 'df24' has no school name
# !Attention! : 'df25' has no school name
# !Attention! : 'df26' has no school name
# !Attention! : 'df31' has no school name

# %%
ss_max_list = ['sor1_max', 'sor2_max', 'sor3_max', 'soch_max']

# %%
for key, df in df_dict.items():
    print(f"'{key}'")
    print(df.info())
# Out:
# 'df1'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   school    755 non-null    object
#  1   fio       755 non-null    object
#  2   grade     755 non-null    int64
#  3   subject   755 non-null    object
#  4   sor1      755 non-null    int64
#  5   sor1_max  755 non-null    int64
#  6   sor2      755 non-null    int64
#  7   sor2_max  755 non-null    float64
#  8   sor3      755 non-null    int64
#  9   sor3_max  755 non-null    float64
#  10  soch      755 non-null    int64
#  11  soch_max  755 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 70.9+ KB
# None
# 'df2'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   school    705 non-null    object
# ...

# %%
df_dict['df26']
# Out:
#      school                fio  grade subject  sor1  sor1_max  sor2  sor2_max  \
# 185     NaN  Әділбек Әбдірахым      8    BIOL  17.0      16.0   0.0       0.0
#
#      sor3  sor3_max  soch  soch_max
# 185   0.0       0.0   0.0       0.0
